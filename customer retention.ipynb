# %% [markdown]
# # Customer retention

# %% [markdown]
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store.

# %% [markdown]
# It has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention.

# %% [markdown]
# Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit.

# %% [markdown]
# The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('customer retention.csv')

# %%
data
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 268                Female         41-50 yaers
# 269                   NaN                 NaN
# 270                   NaN                 NaN
# 271                   NaN                 NaN
# 272                   NaN                 NaN
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 268                             Ghaziabad
# 269                                   NaN
# ...

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 268                Female         41-50 yaers
# 269                   NaN                 NaN
# 270                   NaN                 NaN
# 271                   NaN                 NaN
# 272                   NaN                 NaN
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 268                             Ghaziabad
# 269                                   NaN
# ...

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# The dataset cointains 269 records and 71 features.

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?',
#        '10 What is the operating system (OS) of your device?',
#        '11 What browser do you run on your device to access the website?',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?',
#        '13 After first visit, how do you reach the online retail store?',
#        '14 How much time do you explore the e- retail store before making a purchase decision?',
#        '15 What is your preferred payment Option?',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                        --------------  -----
#  0   1Gender of respondent                                                                                         269 non-null    object
#  1   2 How old are you?                                                                                            269 non-null    object
#  2   3 Which city do you shop online from?                                                                         269 non-null    object
#  3   4 What is the Pin Code of where you shop online from?                                                         269 non-null    float64
# ...

# %% [markdown]
# The dataset is a mix of integer,float ,object(categorical) datatype. There are no null values present in the dataset.

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# 5                  Female         31-40 years
# 6                    Male         41-50 yaers
# 7                    Male         41-50 yaers
# 8                  Female  Less than 20 years
# 9                  Female         31-40 years
# 10                   Male         31-40 years
# 11                 Female         41-50 yaers
# 12                 Female  51 years and above
# 13                 Female         31-40 years
# 14                 Female         21-30 years
# 15                 Female         21-30 years
# 16                   Male         31-40 years
# 17                   Male         41-50 yaers
# 18                 Female         41-50 yaers
# ...

# %%
plt.figure(figsize=[16,8])
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the heatmap it can be said there are no null values present in the dataset.

# %%
sns.countplot(df['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %%
df['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %% [markdown]
# 88 records i.e 33% in this dataset are for Male's and 181 records i.e 67% are for Female's.

# %%
plt.figure(figsize=[16,8])
sns.countplot(df['2 How old are you? '])
plt.show()

# %%
df['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %% [markdown]
# The maximum records i.e 81 out of 269(30%) in this dataset are having age between 31 to 40 years.
# The least records i.e 19 out of 269(7%)in this dataset are having age of 51 years and above.
# From this dataset it can be said the young generation are opting for online shopping as compared to the one's in the age 51 years and above.

# %%
plt.figure(figsize=[16,8])
sns.countplot(df['2 How old are you? '],hue=df['1Gender of respondent'])
plt.show()

# %%
pd.crosstab(df['1Gender of respondent'],df['2 How old are you? '],margins=True)
# Out:
# 2 How old are you?     21-30 years  31-40 years  41-50 yaers  \
# 1Gender of respondent
# Female                          59           51           43
# Male                            20           30           27
# All                             79           81           70
#
# 2 How old are you?     51 years and above  Less than 20 years  All
# 1Gender of respondent
# Female                                 15                  13  181
# Male                                    4                   7   88
# All                                    19                  20  269

# %% [markdown]
# From this dataset it can be said Female's are actively opting for online shopping as compared to Male's counterpart.

# %%
plt.figure(figsize=[16,8])
sns.countplot(df['3 Which city do you shop online from?'])
plt.show()

# %%
df['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# The maximum records i.e 58 out of 269 (22%) are from Delhi and the least records i.e 2 out of 269(0.007%) are from Bulandshahr.

# %% [markdown]
# Delhi is the most preferred choice for online shopping as compared to other cities.

# %%
sns.countplot(df['5 Since How Long You are Shopping Online ?'])
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %%
df['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %% [markdown]
# The maximum records i.e 98 out of 269(36%) are shopping online from last 4 years and above.

# %% [markdown]
# The least records i.e 16 out of 269(0.05%) are shopping online from last 1 to 2 years.

# %%
plt.figure(figsize=[16,8])
sns.countplot(df['6 How many times you have made an online purchase in the past 1 year?'])
plt.show()

# %%
df['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %% [markdown]
# The maximum records i.e 114 out of 269 (42%) are making an online purchase of less than 10 times in a year.
# The least records i.e 10 out of 269 (0.03%) are making an online purchase of 21 to 30 times in a year.

# %%
sns.countplot(df['7 How do you access the internet while shopping on-line?'])
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %%
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
df['7 How do you access the internet while shopping on-line?'].replace('Mobile Internet','Mobile internet',inplace=True)

# %%
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    189
# Wi-Fi               76
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# The maximum records i.e 189 out of 269(70%) are having mobile internet access while shopping on-line.
# The least records i.e 4 out of 269 (0.01%) are having dial-up access while shopping on-line.

# %%
sns.countplot(df['8 Which device do you use to access the online shopping?'])
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %%
df['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# The maximum records i.e 141 out of 269(52%) are using smartphone to access the online shopping.
# The least records i.e 12 out of 269 (0.04%)are using tablet to access the online shopping.

# %%
sns.countplot(df['9 What is the screen size of your mobile device?'])
# Out:
# <AxesSubplot:xlabel='9 What is the screen size of your mobile device?', ylabel='count'>

# %%
df['9 What is the screen size of your mobile device?'].value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?, dtype: int64

# %% [markdown]
# The screen size of most of the mobile phone used in online shopping is 5.5 inches.

# %%
df['10 What is the operating system (OS) of your device?'].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?, dtype: int64

# %% [markdown]
# Window is most preferred OS used for the device used in online shopping.

# %%
sns.countplot(df['11 What browser do you run on your device to access the website?'])
# Out:
# <AxesSubplot:xlabel='11 What browser do you run on your device to access the website?', ylabel='count'>

# %%
df['11 What browser do you run on your device to access the website?'].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?, dtype: int64

# %% [markdown]
# Google chrome is the most preferred browser used in online shopping.

# %%
sns.countplot(df['12 Which channel did you follow to arrive at your favorite online store for the first time?'])
# Out:
# <AxesSubplot:xlabel='12 Which channel did you follow to arrive at your favorite online store for the first time?', ylabel='count'>

# %%
df['12 Which channel did you follow to arrive at your favorite online store for the first time?'].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?, dtype: int64

# %% [markdown]
# The maximum records i.e 230 out of 269 (86%) use search engine for example google,to arrive at the favorite online store for the first time.

# %%
plt.figure(figsize=[16,8])
sns.countplot(df['13 After first visit, how do you reach the online retail store?'])
plt.show()

# %%
df['13 After first visit, how do you reach the online retail store?'].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?, dtype: int64

# %% [markdown]
# The maximum records i.e 87 out of 269 (32%) prefer to arrive at the online retail store via search engine after first visit.

# %%
plt.figure(figsize=[16,8])
sns.countplot(df['14 How much time do you explore the e- retail store before making a purchase decision?'])
plt.show()

# %%
df['14 How much time do you explore the e- retail store before making a purchase decision?'].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?, dtype: int64

# %% [markdown]
# The maximum records i.e 123 out of 269 (46%) take more than 15 minutes to explore the e- retail store before making a purchase decision.

# %%
plt.figure(figsize=[14,8])
sns.countplot(df['15 What is your preferred payment Option?'])
plt.show()

# %%
df['15 What is your preferred payment Option?'].value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?, dtype: int64

# %% [markdown]
# The maximum records i.e 148 out of 269 (55%) prefers credit/debit cards as a payment option.

# %%
sns.countplot(df['15 What is your preferred payment Option?'],hue=df['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='15 What is your preferred payment Option?', ylabel='count'>

# %%
pd.crosstab(df['1Gender of respondent'],df['15 What is your preferred payment Option?'],margins=True)
# Out:
# 15 What is your preferred payment Option?  Cash on delivery (CoD)  \
# 1Gender of respondent
# Female                                                         58
# Male                                                           18
# All                                                            76
#
# 15 What is your preferred payment Option?  Credit/Debit cards  \
# 1Gender of respondent
# Female                                                     92
# Male                                                       56
# All                                                       148
#
# 15 What is your preferred payment Option?  E-wallets (Paytm, Freecharge etc.)  \
# 1Gender of respondent
# Female                                                                     31
# Male                                                                       14
# All                                                                        45
#
# 15 What is your preferred payment Option?  All
# ...

# %% [markdown]
# E-wallets is the least preferred payment option.

# %%
sns.countplot(df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'])
# Out:
# <AxesSubplot:xlabel='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?', ylabel='count'>

# %%
df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'].value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?, dtype: int64

# %% [markdown]
# The maximum records i.e 171 out of 269 (64%) sometimes abandon the shopping cart without making payment.

# %% [markdown]
# The least records i.e 15 out of 269 (0.05%) very frequently abandon the shopping cart without making payment.

# %%
plt.figure(figsize=[14,10])
sns.countplot(df['17 Why did you abandon the “Bag”, “Shopping Cart”?'])
plt.show()

# %%
df['17 Why did you abandon the “Bag”, “Shopping Cart”?'].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?, dtype: int64

# %% [markdown]
# The maximum records i.e 133 out of 269(49%) abandon the Shopping cart in lieu of finding better alternative offer.

# %%
plt.figure(figsize=[10,8])
sns.countplot(df['18 The content on the website must be easy to read and understand'])
plt.show()

# %%
df['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %% [markdown]
# The maximum records i.e 164 out of 269 (61%) strongly agree that the content on the website must be easy to read and understand.

# %%
plt.figure(figsize=[10,8])
sns.countplot(df['19 Information on similar product to the one highlighted  is important for product comparison'])
plt.show()

# %%
df['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts()
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %% [markdown]
# The maximum records i.e 116 out of 269 (43%) strongly agrees that the Information on similar product to the one highlighted  is important for product comparison.

# %%
plt.figure(figsize=[10,8])
sns.countplot(df['20 Complete information on listed seller and product being offered is important for purchase decision.'])
plt.show()

# %%
df['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %% [markdown]
# The maximum records i.e 101 out of 269(38%) agree to know complete information on listed seller and product being offered before deciding whether to buy the product or not.

# %%
plt.figure(figsize=[14,10])
sns.countplot(df['21 All relevant information on listed products must be stated clearly'])
plt.show()

# %%
df['21 All relevant information on listed products must be stated clearly'].value_counts()
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %% [markdown]
# The maximum records i.e 132 out of 269 (49%) agrees with all relevant information on listed products must be stated clearly.

# %%
plt.figure(figsize=[14,10])
sns.countplot(df['22 Ease of navigation in website'])
plt.show()

# %%
df['22 Ease of navigation in website'].value_counts()
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %% [markdown]
# The maximum records i.e 141 out of 269 (52%) strongly agrees with the ease of navigation in website to generate better sales.

# %%
plt.figure(figsize=[10,8])
sns.countplot(df['23 Loading and processing speed'])
plt.show()

# %%
df['23 Loading and processing speed'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: 23 Loading and processing speed, dtype: int64

# %% [markdown]
# The maximum records i.e 115 out of 269 (43%) strongly agrees with the loading and processing speed of the URL to be faster to have better online shopping experience.

# %%
plt.figure(figsize=[10,8])
sns.countplot(df['24 User friendly Interface of the website'])
plt.show()

# %%
df['24 User friendly Interface of the website'].value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %% [markdown]
# The maximum records i.e 189 out of 269 (70%) strongly agrees with the user friendly interface of the website.

# %%
plt.figure(figsize=[10,8])
sns.countplot(df['25 Convenient Payment methods'])
plt.show()

# %%
df['25 Convenient Payment methods'].value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %% [markdown]
# The maximum records i.e 159 out of 269(59%) strongly agrees with convenient payment method.

# %%
sns.countplot(df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'])
# Out:
# <AxesSubplot:xlabel='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time', ylabel='count'>

# %%
df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts()
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %% [markdown]
# The maximum records i.e 141 out of 269(52%) strongly agrees the trust that the online retail store will fulfill its part of the transaction at the stipulated time. Further, trust is an important factor for any business to survive, once that is built the business will blossom like anything.

# %%
sns.countplot(df['27 Empathy (readiness to assist with queries) towards the customers'])
# Out:
# <AxesSubplot:xlabel='27 Empathy (readiness to assist with queries) towards the customers', ylabel='count'>

# %%
df['27 Empathy (readiness to assist with queries) towards the customers'].value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %% [markdown]
# The maximum records i.e 194 out of 269(72%) strongly agrees with the Empathy(readiness to assist with queries) towards the customers should be there in order to affect the repeat purchase intention positively.

# %%
sns.countplot(df['28 Being able to guarantee the privacy of the customer'])
# Out:
# <AxesSubplot:xlabel='28 Being able to guarantee the privacy of the customer', ylabel='count'>

# %%
df['28 Being able to guarantee the privacy of the customer'].value_counts()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %% [markdown]
# The maximum records i.e 185 out of 269 (69%) strongly agree with the gurantee to protect the privacy of the customer.

# %%
sns.countplot(df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'])
# Out:
# <AxesSubplot:xlabel='29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)', ylabel='count'>

# %%
df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts()
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %% [markdown]
# The maximum records i.e 149 out of 269 strongly agree with the availability of several communication channels like email id, phone etc.

# %%
sns.countplot(df['30 Online shopping gives monetary benefit and discounts'])
# Out:
# <AxesSubplot:xlabel='30 Online shopping gives monetary benefit and discounts', ylabel='count'>

# %%
df['30 Online shopping gives monetary benefit and discounts'].value_counts()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %% [markdown]
# The maximum records i.e 105 out of 269(39%) strongly agree to buy products having monetary benefit and discounts.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df['31 Enjoyment is derived from shopping online'])
plt.show()

# %%
df['31 Enjoyment is derived from shopping online'].value_counts()
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %% [markdown]
# The maximum records i.e 86 out of 269(32%) strongly agree to have a sense of enjoyment from shopping online.

# %%
sns.countplot(df['32 Shopping online is convenient and flexible'])
# Out:
# <AxesSubplot:xlabel='32 Shopping online is convenient and flexible', ylabel='count'>

# %%
df['32 Shopping online is convenient and flexible'].value_counts()
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %% [markdown]
# The maximum records i.e 146 out of 269(54%) strongly agree for the online shopping which is convenient and flexible.

# %%
sns.countplot(df['33 Return and replacement policy of the e-tailer is important for purchase decision'])
# Out:
# <AxesSubplot:xlabel='33 Return and replacement policy of the e-tailer is important for purchase decision', ylabel='count'>

# %%
df['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %% [markdown]
# The maximum records i.e 198 out 269 (74%) strongly agree to have a proper/user friendly return and replacement policy.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df['34 Gaining access to loyalty programs is a benefit of shopping online'])
plt.show()

# %%
df['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %% [markdown]
# The maximum records i.e 115 out of 269 strongly agree to have access to loyality programs.

# %%
sns.countplot(df['35 Displaying quality Information on the website improves satisfaction of customers'])
# Out:
# <AxesSubplot:xlabel='35 Displaying quality Information on the website improves satisfaction of customers', ylabel='count'>

# %%
df['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %% [markdown]
# The maximum records i.e 133 out of 269(49%) strongly agree with displaying quality information on the website.

# %%
sns.countplot(df['36 User derive satisfaction while shopping on a good quality website or application'])
# Out:
# <AxesSubplot:xlabel='36 User derive satisfaction while shopping on a good quality website or application', ylabel='count'>

# %%
df['36 User derive satisfaction while shopping on a good quality website or application'].value_counts()
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %% [markdown]
# The maximum records i.e 175 out of 269(65%) strongly agree with having user derive satisfaction i.e having good quality website and application.

# %%
sns.countplot(df['37 Net Benefit derived from shopping online can lead to users satisfaction'])
# Out:
# <AxesSubplot:xlabel='37 Net Benefit derived from shopping online can lead to users satisfaction', ylabel='count'>

# %%
df['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts()
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %% [markdown]
# The maximum records i.e 164 out of 269(61%) strongly agree having net benefit derived from online shopping by the way of discount and other monetary benefits.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df['38 User satisfaction cannot exist without trust'])
plt.show()

# %%
df['38 User satisfaction cannot exist without trust'].value_counts()
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %% [markdown]
# The maximum records i.e 122 out of 269 (45%) strongly agree with user satisfaction cannot exist without trust.

# %%
sns.countplot(df['39 Offering a wide variety of listed product in several category'])
# Out:
# <AxesSubplot:xlabel='39 Offering a wide variety of listed product in several category', ylabel='count'>

# %%
df['39 Offering a wide variety of listed product in several category'].value_counts()
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %% [markdown]
# The maximum records i.e 111 out of 269 (41%) strongly agree for a wide variety of listed products offering in several category.

# %%
sns.countplot(df['40 Provision of complete and relevant product information'])
# Out:
# <AxesSubplot:xlabel='40 Provision of complete and relevant product information', ylabel='count'>

# %%
df['40 Provision of complete and relevant product information'].value_counts()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %% [markdown]
# The maximum records i.e 135 out of 269 (50%) strongly agree with Provision of complete and relevant product information.

# %%
sns.countplot(df['41 Monetary savings'])
# Out:
# <AxesSubplot:xlabel='41 Monetary savings', ylabel='count'>

# %%
df['41 Monetary savings'].value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %% [markdown]
# The maximum records i.e 148 out of 269 (55%) strongly agree with having monetary savings.

# %%
sns.countplot(df['42 The Convenience of patronizing the online retailer'])
# Out:
# <AxesSubplot:xlabel='42 The Convenience of patronizing the online retailer', ylabel='count'>

# %%
df['42 The Convenience of patronizing the online retailer'].value_counts()
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %% [markdown]
# The maximum records i.e 138 out of 269(51%) strongly agree with the Convenience of patronizing the online retailer.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df['43 Shopping on the website gives you the sense of adventure'])
plt.show()

# %%
df['43 Shopping on the website gives you the sense of adventure'].value_counts()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %% [markdown]
# The maximum records i.e 101 out of 269(38%) strongly agree that the shopping on the website gives you the sense of adventure.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df['44 Shopping on your preferred e-tailer enhances your social status'])
plt.show()

# %%
df['44 Shopping on your preferred e-tailer enhances your social status'].value_counts()
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %% [markdown]
# The maximum records i.e 100 out of 269 (37%) are having indifferent opinion related to the shopping on the preferred e-tailer enhances the social status.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df['45 You feel gratification shopping on your favorite e-tailer'])
plt.show()

# %%
df['45 You feel gratification shopping on your favorite e-tailer'].value_counts()
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %% [markdown]
# The maximum records i.e 101 out of 269 (38%) are having indifferent opinion related to the gratification one feels shopping on your favorite e-tailer.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df['46 Shopping on the website helps you fulfill certain roles'])
plt.show()

# %%
df['46 Shopping on the website helps you fulfill certain roles'].value_counts()
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %% [markdown]
# The maximum records i.e 88 out of 269 (33%) are having indifference/agree opinion related to the shopping on the website helps one fulfill certain roles.

# %%
sns.countplot(df['47 Getting value for money spent'])
# Out:
# <AxesSubplot:xlabel='47 Getting value for money spent', ylabel='count'>

# %%
df['47 Getting value for money spent'].value_counts()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %% [markdown]
# The maximum records i.e 149 out of 269 (55%) agree with Getting value for money spent.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df['From the following, tick any (or all) of the online retailers you have shopped from;'])
plt.show()

# %%
df['From the following, tick any (or all) of the online retailers you have shopped from;'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;, dtype: int64

# %%
df1=df.copy()

# %%
df1['option 1']=df1['From the following, tick any (or all) of the online retailers you have shopped from;'].str.split(',').str[0]

# %%
df1['option 2']=df1['From the following, tick any (or all) of the online retailers you have shopped from;'].str.split(',').str[1]

# %%
df1['option 3']=df1['From the following, tick any (or all) of the online retailers you have shopped from;'].str.split(',').str[2]

# %%
df1['option 4']=df1['From the following, tick any (or all) of the online retailers you have shopped from;'].str.split(',').str[3]

# %%
df1['option 5']=df1['From the following, tick any (or all) of the online retailers you have shopped from;'].str.split(',').str[4]

# %%
df1
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# 5                  Female         31-40 years
# 6                    Male         41-50 yaers
# 7                    Male         41-50 yaers
# 8                  Female  Less than 20 years
# 9                  Female         31-40 years
# 10                   Male         31-40 years
# 11                 Female         41-50 yaers
# 12                 Female  51 years and above
# 13                 Female         31-40 years
# 14                 Female         21-30 years
# 15                 Female         21-30 years
# 16                   Male         31-40 years
# 17                   Male         41-50 yaers
# 18                 Female         41-50 yaers
# ...

# %%
sns.countplot(df1['option 1'])
# Out:
# <AxesSubplot:xlabel='option 1', ylabel='count'>

# %%
df1['option 1'].value_counts()
# Out:
# Amazon.in    269
# Name: option 1, dtype: int64

# %% [markdown]
# Amazon is the most prefered online retailer for shopping as all of the records in this dataset have shopped from amazon once.

# %%
sns.countplot(df1['option 2'])
# Out:
# <AxesSubplot:xlabel='option 2', ylabel='count'>

# %%
df1['option 2'].value_counts()
# Out:
#  Flipkart.com    221
#  Paytm.com        32
# Name: option 2, dtype: int64

# %%
sns.countplot(df1['option 3'])
# Out:
# <AxesSubplot:xlabel='option 3', ylabel='count'>

# %%
df1['option 3'].value_counts()
# Out:
#  Paytm.com       118
#  Myntra.com       64
#  Snapdeal.com     27
# Name: option 3, dtype: int64

# %%
sns.countplot(df1['option 4'])
# Out:
# <AxesSubplot:xlabel='option 4', ylabel='count'>

# %%
df1['option 4'].value_counts()
# Out:
#  Myntra.com      82
#  Snapdeal.com    73
# Name: option 4, dtype: int64

# %%
sns.countplot(df1['option 5'])
# Out:
# <AxesSubplot:xlabel='option 5', ylabel='count'>

# %%
df1['option 5'].value_counts()
# Out:
#  Snapdeal.com    82
# Name: option 5, dtype: int64

# %% [markdown]
# Amazon and flipkart is the most preferable choice for online shopping.

# %%
sns.countplot(df1['option 1'],hue=df1['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='option 1', ylabel='count'>

# %%
pd.crosstab(df1['option 1'],df1['1Gender of respondent'],margins=True)
# Out:
# 1Gender of respondent  Female  Male  All
# option 1
# Amazon.in                 181    88  269
# All                       181    88  269

# %%
pd.crosstab(df1['option 2'],df1['1Gender of respondent'],margins=True)
# Out:
# 1Gender of respondent  Female  Male  All
# option 2
#  Flipkart.com             148    73  221
#  Paytm.com                 20    12   32
# All                       168    85  253

# %%
pd.crosstab(df1['option 3'],df1['1Gender of respondent'],margins=True)
# Out:
# 1Gender of respondent  Female  Male  All
# option 3
#  Myntra.com                48    16   64
#  Paytm.com                 70    48  118
#  Snapdeal.com              22     5   27
# All                       140    69  209

# %%
pd.crosstab(df1['option 4'],df1['1Gender of respondent'],margins=True)
# Out:
# 1Gender of respondent  Female  Male  All
# option 4
#  Myntra.com                57    25   82
#  Snapdeal.com              41    32   73
# All                        98    57  155

# %%
pd.crosstab(df1['option 5'],df1['1Gender of respondent'],margins=True)
# Out:
# 1Gender of respondent  Female  Male  All
# option 5
#  Snapdeal.com              57    25   82
# All                        57    25   82

# %% [markdown]
# Most of the Female's and Male's prefered to shop from amazon and flipkart.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Easy to use website or application'])
plt.show()

# %%
df1['Easy to use website or application'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %%
df1['option11']=df1['Easy to use website or application'].str.split(',').str[0]

# %%
df1['option21']=df1['Easy to use website or application'].str.split(',').str[1]

# %%
df1['option31']=df1['Easy to use website or application'].str.split(',').str[2]

# %%
df1['option41']=df1['Easy to use website or application'].str.split(',').str[3]

# %%
df1['option51']=df1['Easy to use website or application'].str.split(',').str[4]

# %%
sns.countplot(df1['option11'])
# Out:
# <AxesSubplot:xlabel='option11', ylabel='count'>

# %%
df1['option11'].value_counts()
# Out:
# Amazon.in       249
# Paytm.com        12
# Flipkart.com      8
# Name: option11, dtype: int64

# %%
sns.countplot(df1['option21'])
# Out:
# <AxesSubplot:xlabel='option21', ylabel='count'>

# %%
df1['option21'].value_counts()
# Out:
#  Flipkart.com    193
#  Paytm.com        27
# Name: option21, dtype: int64

# %%
df1['option31'].value_counts()
# Out:
#  Paytm.com     86
#  Myntra.com    83
# Name: option31, dtype: int64

# %%
df1['option41'].value_counts()
# Out:
#  Snapdeal.com    66
#  Myntra.com      64
# Name: option41, dtype: int64

# %%
df1['option51'].value_counts()
# Out:
#  Snapdeal.com    64
# Name: option51, dtype: int64

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to ease of using website or application.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Visual appealing web-page layout'])
plt.show()

# %%
df1['option 11']=df1['Visual appealing web-page layout'].str.split(',').str[0]

# %%
df1['option 21']=df1['Visual appealing web-page layout'].str.split(',').str[1]

# %%
df1['option 31']=df1['Visual appealing web-page layout'].str.split(',').str[2]

# %%
df1['option 41']=df1['Visual appealing web-page layout'].str.split(',').str[3]

# %%
df1['option 51']=df1['Visual appealing web-page layout'].str.split(',').str[4]

# %%
sns.countplot(df1['option 11'])
# Out:
# <AxesSubplot:xlabel='option 11', ylabel='count'>

# %%
df1['option 11'].value_counts()
# Out:
# Amazon.in       227
# Flipkart.com     27
# Myntra.com       15
# Name: option 11, dtype: int64

# %%
sns.countplot(df1['option 21'])
# Out:
# <AxesSubplot:xlabel='option 21', ylabel='count'>

# %%
df1['option 21'].value_counts()
# Out:
#  Flipkart.com    148
#  Myntra.com       30
#  Paytm.com        20
# Name: option 21, dtype: int64

# %%
df1['option 21'].value_counts()
# Out:
#  Flipkart.com    148
#  Myntra.com       30
#  Paytm.com        20
# Name: option 21, dtype: int64

# %%
df1['option 31'].value_counts()
# Out:
#  Paytm.com     47
#  Myntra.com    34
# Name: option 31, dtype: int64

# %%
sns.countplot(df1['option 41'])
# Out:
# <AxesSubplot:xlabel='option 41', ylabel='count'>

# %%
df1['option 41'].value_counts()
# Out:
#  Myntra.com      36
#  Snapdeal.com    25
# Name: option 41, dtype: int64

# %%
df1['option 51'].value_counts()
# Out:
#  Snapdeal.com    36
# Name: option 51, dtype: int64

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to visual appealing of the web page layout.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Wild variety of product on offer'])
plt.show()

# %%
df1['Wild variety of product on offer'].value_counts()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Myntra.com                                            15
# Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %%
df1['options 1']=df1['Wild variety of product on offer'].str.split(',').str[0]

# %%
df1['options 2']=df1['Wild variety of product on offer'].str.split(',').str[1]

# %%
df1['options 3']=df1['Wild variety of product on offer'].str.split(',').str[2]

# %%
df1['options 4']=df1['Wild variety of product on offer'].str.split(',').str[3]

# %%
df1['options 5']=df1['Wild variety of product on offer'].str.split(',').str[4]

# %%
sns.countplot(df1['options 1'])
# Out:
# <AxesSubplot:xlabel='options 1', ylabel='count'>

# %%
sns.countplot(df1['options 2'])
# Out:
# <AxesSubplot:xlabel='options 2', ylabel='count'>

# %%
sns.countplot(df1['options 3'])
# Out:
# <AxesSubplot:xlabel='options 3', ylabel='count'>

# %%
sns.countplot(df1['options 4'])
# Out:
# <AxesSubplot:xlabel='options 4', ylabel='count'>

# %%
df1['options 1'].value_counts()
# Out:
# Amazon.in       220
# Flipkart.com     27
# Myntra.com       15
# Paytm.com         7
# Name: options 1, dtype: int64

# %%
df1['options 2'].value_counts()
# Out:
#  Flipkart.com    157
#  Myntra.com       35
# Name: options 2, dtype: int64

# %%
df1['options 3'].value_counts()
# Out:
#  Myntra.com    14
#  Paytm.com     13
# Name: options 3, dtype: int64

# %%
df1['options 4'].value_counts()
# Out:
#  Snapdeal.com    14
# Name: options 4, dtype: int64

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to variety of products on offer.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Complete, relevant description information of products'])
plt.show()

# %%
df1['Complete, relevant description information of products'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %%
df1['options 11']=df1['Complete, relevant description information of products'].str.split(',').str[0]

# %%
df1['options 21']=df1['Complete, relevant description information of products'].str.split(',').str[1]

# %%
df1['options 31']=df1['Complete, relevant description information of products'].str.split(',').str[2]

# %%
df1['options 41']=df1['Complete, relevant description information of products'].str.split(',').str[3]

# %%
df1['options 51']=df1['Complete, relevant description information of products'].str.split(',').str[4]

# %%
sns.countplot(df1['options 11'])
# Out:
# <AxesSubplot:xlabel='options 11', ylabel='count'>

# %%
sns.countplot(df1['options 21'])
# Out:
# <AxesSubplot:xlabel='options 21', ylabel='count'>

# %%
sns.countplot(df1['options 31'])
# Out:
# <AxesSubplot:xlabel='options 31', ylabel='count'>

# %%
sns.countplot(df1['options 41'])
# Out:
# <AxesSubplot:xlabel='options 41', ylabel='count'>

# %%
sns.countplot(df1['options 51'])
# Out:
# <AxesSubplot:xlabel='options 51', ylabel='count'>

# %%
df1['options 11'].value_counts()
# Out:
# Amazon.in       238
# Flipkart.com     19
# Snapdeal.com     12
# Name: options 11, dtype: int64

# %%
df1['options 21'].value_counts()
# Out:
#  Flipkart.com    175
#  Paytm.com        20
#  Snapdeal.com     11
# Name: options 21, dtype: int64

# %%
df1['options 31'].value_counts()
# Out:
#  Myntra.com      49
#  Paytm.com       39
#  Snapdeal.com     7
# Name: options 31, dtype: int64

# %%
df1['options 41'].value_counts()
# Out:
#  Myntra.com      15
#  Snapdeal.com    14
# Name: options 41, dtype: int64

# %%
df1['options 51'].value_counts()
# Out:
#  Snapdeal.com    15
# Name: options 51, dtype: int64

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to complete, relevant description information of products.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Fast loading website speed of website and application'])
plt.show()

# %%
df1['Fast loading website speed of website and application'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %%
df1['options1']=df1['Fast loading website speed of website and application'].str.split(',').str[0]

# %%
df1['options2']=df1['Fast loading website speed of website and application'].str.split(',').str[1]

# %%
df1['options3']=df1['Fast loading website speed of website and application'].str.split(',').str[2]

# %%
df1['options4']=df1['Fast loading website speed of website and application'].str.split(',').str[3]

# %%
df1['options5']=df1['Fast loading website speed of website and application'].str.split(',').str[4]

# %%
sns.countplot(df1['options1'])
# Out:
# <AxesSubplot:xlabel='options1', ylabel='count'>

# %%
sns.countplot(df1['options2'])
# Out:
# <AxesSubplot:xlabel='options2', ylabel='count'>

# %%
sns.countplot(df1['options3'])
# Out:
# <AxesSubplot:xlabel='options3', ylabel='count'>

# %%
sns.countplot(df1['options4'])
# Out:
# <AxesSubplot:xlabel='options4', ylabel='count'>

# %%
sns.countplot(df1['options5'])
# Out:
# <AxesSubplot:xlabel='options5', ylabel='count'>

# %%
df1['options1'].value_counts()
# Out:
# Amazon.in       249
# Snapdeal.com     12
# Flipkart.com      8
# Name: options1, dtype: int64

# %%
df1['options2'].value_counts()
# Out:
#  Flipkart.com    154
#  Paytm.com        44
# Name: options2, dtype: int64

# %%
df1['options3'].value_counts()
# Out:
#  Paytm.com       55
#  Myntra.com      44
#  Snapdeal.com    25
# Name: options3, dtype: int64

# %%
df1['options4'].value_counts()
# Out:
#  Myntra.com      30
#  Snapdeal.com    14
# Name: options4, dtype: int64

# %%
df1['options5'].value_counts()
# Out:
#  Snapdeal.com    30
# Name: options5, dtype: int64

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to fast loading of website and application.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Reliability of the website or application'])
plt.show()

# %%
df1['Reliability of the website or application'].value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %%
df1['options11']=df1['Reliability of the website or application'].str.split(',').str[0]

# %%
df1['options21']=df1['Reliability of the website or application'].str.split(',').str[1]

# %%
df1['options31']=df1['Reliability of the website or application'].str.split(',').str[2]

# %%
df1['options41']=df1['Reliability of the website or application'].str.split(',').str[3]

# %%
df1['options51']=df1['Reliability of the website or application'].str.split(',').str[4]

# %%
sns.countplot(df1['options11'])
# Out:
# <AxesSubplot:xlabel='options11', ylabel='count'>

# %%
sns.countplot(df1['options21'])
# Out:
# <AxesSubplot:xlabel='options21', ylabel='count'>

# %%
sns.countplot(df1['options31'])
# Out:
# <AxesSubplot:xlabel='options31', ylabel='count'>

# %%
sns.countplot(df1['options41'])
# Out:
# <AxesSubplot:xlabel='options41', ylabel='count'>

# %%
df1['options11'].value_counts()
# Out:
# Amazon.in       227
# Myntra.com       15
# Flipkart.com     15
# Paytm.com        12
# Name: options11, dtype: int64

# %%
df1['options21'].value_counts()
# Out:
#  Flipkart.com    131
#  Paytm.com        35
# Name: options21, dtype: int64

# %%
df1['options31'].value_counts()
# Out:
#  Paytm.com       49
#  Myntra.com      49
#  Snapdeal.com    18
# Name: options31, dtype: int64

# %%
df1['options41'].value_counts()
# Out:
#  Snapdeal.com    27
# Name: options41, dtype: int64

# %%
df1['options51'].value_counts()
# Out:
# Series([], Name: options51, dtype: int64)

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to reliability of the website or application.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Quickness to complete purchase'])
plt.show()

# %%
df1['retailer 1']=df1['Quickness to complete purchase'].str.split(',').str[0]

# %%
df1['retailer 2']=df1['Quickness to complete purchase'].str.split(',').str[1]

# %%
df1['retailer 3']=df1['Quickness to complete purchase'].str.split(',').str[2]

# %%
df1['retailer 4']=df1['Quickness to complete purchase'].str.split(',').str[3]

# %%
df1['retailer 5']=df1['Quickness to complete purchase'].str.split(',').str[4]

# %%
sns.countplot(df1['retailer 1'])
# Out:
# <AxesSubplot:xlabel='retailer 1', ylabel='count'>

# %%
sns.countplot(df1['retailer 2'])
# Out:
# <AxesSubplot:xlabel='retailer 2', ylabel='count'>

# %%
sns.countplot(df1['retailer 3'])
# Out:
# <AxesSubplot:xlabel='retailer 3', ylabel='count'>

# %%
sns.countplot(df1['retailer 4'])
# Out:
# <AxesSubplot:xlabel='retailer 4', ylabel='count'>

# %%
sns.countplot(df1['retailer 5'])
# Out:
# <AxesSubplot:xlabel='retailer 5', ylabel='count'>

# %%
df1['retailer 1'].value_counts()
# Out:
# Amazon.com      215
# Flipkart.com     29
# Paytm.com        25
# Name: retailer 1, dtype: int64

# %%
df1['retailer 2'].value_counts()
# Out:
#  Flipkart.com    129
#  Paytm.com        20
#  Myntra.com       14
# Name: retailer 2, dtype: int64

# %%
df1['retailer 3'].value_counts()
# Out:
#  Paytm.com     62
#  Myntra.com    50
#  Snapdeal      14
# Name: retailer 3, dtype: int64

# %%
df1['retailer 4'].value_counts()
# Out:
#  Myntra.com    15
# Name: retailer 4, dtype: int64

# %%
df1['retailer 5'].value_counts()
# Out:
#  Snapdeal    15
# Name: retailer 5, dtype: int64

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to Quickness to complete purchase.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Availability of several payment options'])
plt.show()

# %%
df1['Availability of several payment options'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %%
df1['retailer1']=df1['Availability of several payment options'].str.split(',').str[0]

# %%
df1['retailer2']=df1['Availability of several payment options'].str.split(',').str[1]

# %%
df1['retailer3']=df1['Availability of several payment options'].str.split(',').str[2]

# %%
df1['retailer4']=df1['Availability of several payment options'].str.split(',').str[3]

# %%
df1['retailer5']=df1['Availability of several payment options'].str.split(',').str[4]

# %%
sns.countplot(df1['retailer1'])
# Out:
# <AxesSubplot:xlabel='retailer1', ylabel='count'>

# %%
sns.countplot(df1['retailer2'])
# Out:
# <AxesSubplot:xlabel='retailer2', ylabel='count'>

# %%
sns.countplot(df1['retailer3'])
# Out:
# <AxesSubplot:xlabel='retailer3', ylabel='count'>

# %%
sns.countplot(df1['retailer4'])
# Out:
# <AxesSubplot:xlabel='retailer4', ylabel='count'>

# %%
sns.countplot(df1['retailer5'])
# Out:
# <AxesSubplot:xlabel='retailer5', ylabel='count'>

# %%
df1['retailer1'].value_counts()
# Out:
# Amazon.in       215
# Patym.com        32
# Flipkart.com     22
# Name: retailer1, dtype: int64

# %%
df1['retailer2'].value_counts()
# Out:
#  Flipkart.com    181
#  Myntra.com       34
#  Patym.com        11
# Name: retailer2, dtype: int64

# %%
df1['retailer3'].value_counts()
# Out:
#  Myntra.com      59
#  Patym.com       39
#  Snapdeal.com    32
# Name: retailer3, dtype: int64

# %%
df1['retailer4'].value_counts()
# Out:
#  Myntra.com      39
#  Snapdeal.com    19
# Name: retailer4, dtype: int64

# %%
df1['retailer5'].value_counts()
# Out:
#  Snapdeal.com    39
# Name: retailer5, dtype: int64

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to Availability of several payment options excepted.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Speedy order delivery '])
plt.show()

# %%
df1['Speedy order delivery '].value_counts()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Flipkart.com                               15
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %%
df1['retailer 11']=df1['Speedy order delivery '].str.split(',').str[0]

# %%
df1['retailer 21']=df1['Speedy order delivery '].str.split(',').str[1]

# %%
df1['retailer 31']=df1['Speedy order delivery '].str.split(',').str[2]

# %%
df1['retailer 41']=df1['Speedy order delivery '].str.split(',').str[3]

# %%
df1['retailer 51']=df1['Speedy order delivery '].str.split(',').str[4]

# %%
df1['retailer 11'].value_counts()
# Out:
# Amazon.in       240
# Flipkart.com     29
# Name: retailer 11, dtype: int64

# %%
df1['retailer 21'].value_counts()
# Out:
#  Flipkart.com    133
#  Myntra.com       14
# Name: retailer 21, dtype: int64

# %%
df1['retailer 31'].value_counts()
# Out:
#  Snapdeal.com    50
#  Myntra.com      15
# Name: retailer 31, dtype: int64

# %%
df1['retailer 41'].value_counts()
# Out:
# Series([], Name: retailer 41, dtype: int64)

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to speedy order delivery.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Privacy of customers’ information'])
plt.show()

# %%
df1['Privacy of customers’ information'].value_counts()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Myntra.com                                                      15
# Flipkart.com                                                    15
# Amazon.in, Paytm.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64

# %%
df1['retailers11']=df1['Privacy of customers’ information'].str.split(',').str[0]

# %%
df1['retailers21']=df1['Privacy of customers’ information'].str.split(',').str[1]

# %%
df1['retailers31']=df1['Privacy of customers’ information'].str.split(',').str[2]

# %%
df1['retailers41']=df1['Privacy of customers’ information'].str.split(',').str[3]

# %%
df1['retailers51']=df1['Privacy of customers’ information'].str.split(',').str[4]

# %%
df1['retailers11'].value_counts()
# Out:
# Amazon.in       221
# Paytm.com        18
# Myntra.com       15
# Flipkart.com     15
# Name: retailers11, dtype: int64

# %%
df1['retailers21'].value_counts()
# Out:
#  Flipkart.com    135
#  Paytm.com        15
# Name: retailers21, dtype: int64

# %%
df1['retailers31'].value_counts()
# Out:
#  Myntra.com      39
#  Paytm.com       35
#  Snapdeal.com     7
# Name: retailers31, dtype: int64

# %%
df1['retailers41'].value_counts()
# Out:
#  Myntra.com      24
#  Snapdeal.com    14
# Name: retailers41, dtype: int64

# %%
df1['retailers51'].value_counts()
# Out:
#  Snapdeal.com    24
# Name: retailers51, dtype: int64

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to Privacy related to customer's information.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Security of customer financial information'])
plt.show()

# %%
df1['Security of customer financial information'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Paytm.com                                                       15
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %%
df1['retailers 1']=df1['Security of customer financial information'].str.split(',').str[0]

# %%
df1['retailers 2']=df1['Security of customer financial information'].str.split(',').str[1]

# %%
df1['retailers 3']=df1['Security of customer financial information'].str.split(',').str[2]

# %%
df1['retailers 4']=df1['Security of customer financial information'].str.split(',').str[3]

# %%
df1['retailers 5']=df1['Security of customer financial information'].str.split(',').str[4]

# %%
df1['retailers 1'].value_counts()
# Out:
# Amazon.in       206
# Flipkart.com     33
# Paytm.com        15
# Myntra.com       15
# Name: retailers 1, dtype: int64

# %%
df1['retailers 2'].value_counts()
# Out:
#  Flipkart.com    116
#  Paytm.com        20
#  Snapdeal.com     19
# Name: retailers 2, dtype: int64

# %%
df1['retailers 3'].value_counts()
# Out:
#  Paytm.com       53
#  Myntra.com      34
#  Snapdeal.com    25
# Name: retailers 3, dtype: int64

# %%
df1['retailers 4'].value_counts()
# Out:
#  Myntra.com      42
#  Snapdeal.com    14
# Name: retailers 4, dtype: int64

# %%
df1['retailers 5'].value_counts()
# Out:
#  Snapdeal.com    42
# Name: retailers 5, dtype: int64

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to Security of customer financial information.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Perceived Trustworthiness'])
plt.show()

# %%
df1['Perceived Trustworthiness'].value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %%
df1['retail 1']=df1['Perceived Trustworthiness'].str.split(',').str[0]

# %%
df1['retail 2']=df1['Perceived Trustworthiness'].str.split(',').str[1]

# %%
df1['retail 3']=df1['Perceived Trustworthiness'].str.split(',').str[2]

# %%
df1['retail 4']=df1['Perceived Trustworthiness'].str.split(',').str[3]

# %%
df1['retail 5']=df1['Perceived Trustworthiness'].str.split(',').str[4]

# %%
df1['retail 1'].value_counts()
# Out:
# Amazon.in       227
# Flipkart.com     27
# Myntra.com       15
# Name: retail 1, dtype: int64

# %%
df1['retail 2'].value_counts()
# Out:
#  Flipkart.com    116
#  Myntra.com       35
# Name: retail 2, dtype: int64

# %%
df1['retail 3'].value_counts()
# Out:
#  Snapdeal.com    36
#  Myntra.com      25
#  Paytm.com       24
# Name: retail 3, dtype: int64

# %%
df1['retail 4'].value_counts()
# Out:
#  Snapdeal.com    25
#  Myntra.com      13
# Name: retail 4, dtype: int64

# %%
df1['retail 5'].value_counts()
# Out:
#  Snapdeal.com    13
# Name: retail 5, dtype: int64

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to Perceived Trustworthiness.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Presence of online assistance through multi-channel'])
plt.show()

# %%
df1['Presence of online assistance through multi-channel'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %%
df1['retail1']=df1['Presence of online assistance through multi-channel'].str.split(',').str[0]

# %%
df1['retail2']=df1['Presence of online assistance through multi-channel'].str.split(',').str[1]

# %%
df1['retail3']=df1['Presence of online assistance through multi-channel'].str.split(',').str[2]

# %%
df1['retail4']=df1['Presence of online assistance through multi-channel'].str.split(',').str[3]

# %%
df1['retail5']=df1['Presence of online assistance through multi-channel'].str.split(',').str[4]

# %%
df1['retail1'].value_counts()
# Out:
# Amazon.in       229
# Myntra.com       20
# Paytm.com        12
# Flipkart.com      8
# Name: retail1, dtype: int64

# %%
df1['retail2'].value_counts()
# Out:
#  Flipkart.com    128
#  Snapdeal         26
#  Myntra.com       15
# Name: retail2, dtype: int64

# %%
df1['retail3'].value_counts()
# Out:
#  Myntra.com    76
#  Paytm.com     13
# Name: retail3, dtype: int64

# %%
df1['retail4'].value_counts()
# Out:
#  Snapdeal    61
# Name: retail4, dtype: int64

# %%
df1['retail5'].value_counts()
# Out:
# Series([], Name: retail5, dtype: int64)

# %% [markdown]
# Amazon and flipkart online retailer are prefered choice when it comes to Presence of online assistance through multi-channel.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Longer time to get logged in (promotion, sales period)'])
plt.show()

# %%
df1['Longer time to get logged in (promotion, sales period)'].value_counts()
# Out:
# Amazon.in                                57
# Paytm.com                                38
# Amazon.in, Flipkart.com                  38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %%
df1['retail 11']=df1['Longer time to get logged in (promotion, sales period)'].str.split(',').str[0]

# %%
df1['retail 21']=df1['Longer time to get logged in (promotion, sales period)'].str.split(',').str[1]

# %%
df1['retail 31']=df1['Longer time to get logged in (promotion, sales period)'].str.split(',').str[2]

# %%
df1['retail 41']=df1['Longer time to get logged in (promotion, sales period)'].str.split(',').str[4]

# %%
df1['retail 51']=df1['Longer time to get logged in (promotion, sales period)'].str.split(',').str[5]

# %%
df1['retail 11'].value_counts()
# Out:
# Amazon.in       135
# Paytm.com        38
# Flipkart.com     36
# Myntra.com       35
# Snapdeal.com     25
# Name: retail 11, dtype: int64

# %%
df1['retail 21'].value_counts()
# Out:
#  Flipkart.com    67
#  Paytm.com       39
# Name: retail 21, dtype: int64

# %%
df1['retail 31'].value_counts()
# Out:
#  Snapdeal.com    42
# Name: retail 31, dtype: int64

# %%
df1['retail 41'].value_counts()
# Out:
# Series([], Name: retail 41, dtype: int64)

# %% [markdown]
# Amazon and flipkart online retailer takes longer time to get logged in when it comes to promotion and sales period.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Longer time in displaying graphics and photos (promotion, sales period)'])
plt.show()

# %%
df1['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %%
df1['retail11']=df1['Longer time in displaying graphics and photos (promotion, sales period)'].str.split(',').str[0]

# %%
df1['retail21']=df1['Longer time in displaying graphics and photos (promotion, sales period)'].str.split(',').str[1]

# %%
df1['retail31']=df1['Longer time in displaying graphics and photos (promotion, sales period)'].str.split(',').str[2]

# %%
df1['retail41']=df1['Longer time in displaying graphics and photos (promotion, sales period)'].str.split(',').str[3]

# %%
df1['retail51']=df1['Longer time in displaying graphics and photos (promotion, sales period)'].str.split(',').str[4]

# %%
df1['retail11'].value_counts()
# Out:
# Amazon.in       126
# Myntra.com       60
# Snapdeal.com     34
# Flipkart.com     34
# Paytm.com        15
# Name: retail11, dtype: int64

# %%
df1['retail21'].value_counts()
# Out:
#  Flipkart.com    60
#  Snapdeal.com    44
#  Myntra.com      14
#  Paytm.com       13
# Name: retail21, dtype: int64

# %%
df1['retail31'].value_counts()
# Out:
#  Snapdeal.com    14
# Name: retail31, dtype: int64

# %%
df1['retail41'].value_counts()
# Out:
# Series([], Name: retail41, dtype: int64)

# %% [markdown]
# Amazon and flipkart online retailer takes Longer time in displaying graphics and photos (promotion, sales period).

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Late declaration of price (promotion, sales period)'])
plt.show()

# %%
df1['Late declaration of price (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Amazon.in                  38
# Flipkart.com               38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %% [markdown]
# When it comes to late declaration of price pertaining to promotion and sales period Myntra is at top position as comapred to others.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Limited mode of payment on most products (promotion, sales period)'])
plt.show()

# %%
df1['Limited mode of payment on most products (promotion, sales period)'].value_counts()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
df1['source 1']=df1['Limited mode of payment on most products (promotion, sales period)'].str.split(',').str[0]

# %%
df1['source 2']=df1['Limited mode of payment on most products (promotion, sales period)'].str.split(',').str[1]

# %%
df1['source 3']=df1['Limited mode of payment on most products (promotion, sales period)'].str.split(',').str[2]

# %%
df1['source 4']=df1['Limited mode of payment on most products (promotion, sales period)'].str.split(',').str[3]

# %%
df1['source 5']=df1['Limited mode of payment on most products (promotion, sales period)'].str.split(',').str[4]

# %%
df1['source 1'].value_counts()
# Out:
# Amazon.in       104
# Snapdeal.com     87
# Paytm.com        40
# Flipkart.com     31
# Myntra.com        7
# Name: source 1, dtype: int64

# %%
df1['source 2'].value_counts()
# Out:
#  Flipkart.com    29
#  Snapdeal.com    22
#  Paytm.com       13
# Name: source 2, dtype: int64

# %%
df1['source 3'].value_counts()
# Out:
# Series([], Name: source 3, dtype: int64)

# %% [markdown]
# When it comes to limited mode of payments on most products snapdeal is at the top as compared to others.

# %%
plt.figure(figsize=[12,10])
sns.countplot(df1['Longer delivery period'])
plt.show()

# %%
df1['Longer delivery period'].value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Paytm.com, Snapdeal.com    26
# Myntra.com                 26
# Name: Longer delivery period, dtype: int64

# %%
df1['source1']=df1['Longer delivery period'].str.split(',').str[0]

# %%
df1['source2']=df1['Longer delivery period'].str.split(',').str[1]

# %%
df1['source1'].value_counts()
# Out:
# Paytm.com       98
# Snapdeal.com    64
# Flipkart.com    44
# Amazon.in       37
# Myntra.com      26
# Name: source1, dtype: int64

# %%
df1['source2'].value_counts()
# Out:
#  Snapdeal.com    26
# Name: source2, dtype: int64

# %% [markdown]
# When it comes to longer delivery period snapdeal is at top as compared to others.

# %%
plt.figure(figsize=[20,8])
sns.countplot(df1['Which of the Indian online retailer would you recommend to a friend?'])
plt.show()

# %%
df1['Which of the Indian online retailer would you recommend to a friend?'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %% [markdown]
# Amazon, the online retailer is the first choice to be recommended to a friend.

# %% [markdown]
# Flipkart,the online retailer is the second choice to be recommended to a friend.
