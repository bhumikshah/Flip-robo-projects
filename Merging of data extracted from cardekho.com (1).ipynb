# %%
import pandas as pd

# %%
data=pd.read_csv('cars details.csv')

# %%
data
# Out:
#      Unnamed: 0            car_details variant used_kilometer    fuel  \
# 0             0      2008 Maruti Swift  Manual     73,000 kms  Petrol
# 1             1       2011 Hyundai i20  Manual     70,000 kms  Petrol
# 2             2  2015 Mahindra TUV 300  Manual     67,000 kms  Diesel
# 3             3   2014 Mahindra XUV500  Manual     90,000 kms  Diesel
# 4             4       2013 Skoda Rapid  Manual     63,000 kms  Diesel
# ..          ...                    ...     ...            ...     ...
# 359         359    2015 Maruti Wagon R  Manual     36,000 kms     CNG
# 360         360   2016 Volkswagen Polo  Manual     58,737 kms  Diesel
# 361         361       2013 Hyundai i20  Manual     59,901 kms  Petrol
# 362         362        2018 Honda City  Manual     50,563 kms  Petrol
# 363         363        2018 Honda BR-V  Manual     39,303 kms  Petrol
#
#             owner location     mileage      Price
# 0    Second Owner   Mumbai   16.1 kmpl  2.15 Lakh
# ...

# %%
df1=pd.DataFrame(data)

# %%
df1.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df1
# Out:
#                car_details variant used_kilometer    fuel         owner  \
# 0        2008 Maruti Swift  Manual     73,000 kms  Petrol  Second Owner
# 1         2011 Hyundai i20  Manual     70,000 kms  Petrol   First Owner
# 2    2015 Mahindra TUV 300  Manual     67,000 kms  Diesel   First Owner
# 3     2014 Mahindra XUV500  Manual     90,000 kms  Diesel   First Owner
# 4         2013 Skoda Rapid  Manual     63,000 kms  Diesel  Second Owner
# ..                     ...     ...            ...     ...           ...
# 359    2015 Maruti Wagon R  Manual     36,000 kms     CNG   First Owner
# 360   2016 Volkswagen Polo  Manual     58,737 kms  Diesel   First Owner
# 361       2013 Hyundai i20  Manual     59,901 kms  Petrol   First Owner
# 362        2018 Honda City  Manual     50,563 kms  Petrol   First Owner
# 363        2018 Honda BR-V  Manual     39,303 kms  Petrol   First Owner
#
#     location     mileage      Price
# 0     Mumbai   16.1 kmpl  2.15 Lakh
# ...

# %%
df1.drop('mileage',axis=1,inplace=True)

# %%
df1
# Out:
#                car_details variant used_kilometer    fuel         owner  \
# 0        2008 Maruti Swift  Manual     73,000 kms  Petrol  Second Owner
# 1         2011 Hyundai i20  Manual     70,000 kms  Petrol   First Owner
# 2    2015 Mahindra TUV 300  Manual     67,000 kms  Diesel   First Owner
# 3     2014 Mahindra XUV500  Manual     90,000 kms  Diesel   First Owner
# 4         2013 Skoda Rapid  Manual     63,000 kms  Diesel  Second Owner
# ..                     ...     ...            ...     ...           ...
# 359    2015 Maruti Wagon R  Manual     36,000 kms     CNG   First Owner
# 360   2016 Volkswagen Polo  Manual     58,737 kms  Diesel   First Owner
# 361       2013 Hyundai i20  Manual     59,901 kms  Petrol   First Owner
# 362        2018 Honda City  Manual     50,563 kms  Petrol   First Owner
# 363        2018 Honda BR-V  Manual     39,303 kms  Petrol   First Owner
#
#     location      Price
# 0     Mumbai  2.15 Lakh
# 1     Mumbai  3.15 Lakh
# 2     Mumbai  7.15 Lakh
# ...

# %%
data1=pd.read_csv('cars1details.csv')

# %%
data1
# Out:
#      Unnamed: 0             car_details    variant used_kilometer    fuel  \
# 0             0        2020 Maruti Eeco     Manual     19,627 kms  Petrol
# 1             1        2016 Maruti Eeco     Manual     45,347 kms  Petrol
# 2             2        2012 Maruti Eeco     Manual     57,341 kms  Petrol
# 3             3        2020 Maruti Eeco     Manual     17,116 kms  Petrol
# 4             4        2019 Maruti Eeco     Manual     14,161 kms  Petrol
# ..          ...                     ...        ...            ...     ...
# 955         955   2018 Ford Figo Aspire     Manual     10,000 kms  Petrol
# 956         956       2012 Maruti Swift     Manual     76,000 kms  Diesel
# 957         957    2017 Maruti Alto 800     Manual     25,000 kms  Petrol
# 958         958        2006 Ford Fiesta     Manual   1,70,000 kms  Petrol
# 959         959  2018 Hyundai Grand i10  Automatic   1,00,000 kms  Petrol
#
#             owner   location      Price
# ...

# %%
df2=pd.DataFrame(data1)

# %%
df2
# Out:
#      Unnamed: 0             car_details    variant used_kilometer    fuel  \
# 0             0        2020 Maruti Eeco     Manual     19,627 kms  Petrol
# 1             1        2016 Maruti Eeco     Manual     45,347 kms  Petrol
# 2             2        2012 Maruti Eeco     Manual     57,341 kms  Petrol
# 3             3        2020 Maruti Eeco     Manual     17,116 kms  Petrol
# 4             4        2019 Maruti Eeco     Manual     14,161 kms  Petrol
# ..          ...                     ...        ...            ...     ...
# 955         955   2018 Ford Figo Aspire     Manual     10,000 kms  Petrol
# 956         956       2012 Maruti Swift     Manual     76,000 kms  Diesel
# 957         957    2017 Maruti Alto 800     Manual     25,000 kms  Petrol
# 958         958        2006 Ford Fiesta     Manual   1,70,000 kms  Petrol
# 959         959  2018 Hyundai Grand i10  Automatic   1,00,000 kms  Petrol
#
#             owner   location      Price
# ...

# %%
df2.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df2
# Out:
#                 car_details    variant used_kilometer    fuel         owner  \
# 0          2020 Maruti Eeco     Manual     19,627 kms  Petrol     1st Owner
# 1          2016 Maruti Eeco     Manual     45,347 kms  Petrol     1st Owner
# 2          2012 Maruti Eeco     Manual     57,341 kms  Petrol     1st Owner
# 3          2020 Maruti Eeco     Manual     17,116 kms  Petrol     1st Owner
# 4          2019 Maruti Eeco     Manual     14,161 kms  Petrol     1st Owner
# ..                      ...        ...            ...     ...           ...
# 955   2018 Ford Figo Aspire     Manual     10,000 kms  Petrol   First Owner
# 956       2012 Maruti Swift     Manual     76,000 kms  Diesel   Third Owner
# 957    2017 Maruti Alto 800     Manual     25,000 kms  Petrol   First Owner
# 958        2006 Ford Fiesta     Manual   1,70,000 kms  Petrol  Second Owner
# 959  2018 Hyundai Grand i10  Automatic   1,00,000 kms  Petrol   First Owner
#
#       location      Price
# 0    Ahmedabad   4.7 Lakh
# ...

# %%
data3=pd.read_csv('cars2details.csv')

# %%
data3
# Out:
#      Unnamed: 0           car_details    variant used_kilometer    fuel  \
# 0             0   2019 Maruti Celerio  Automatic     37,381 kms  Petrol
# 1             1       2016 Tata Tiago     Manual     65,676 kms  Petrol
# 2             2   2017 Renault Duster  Automatic     23,322 kms  Diesel
# 3             3  2015 Maruti Alto 800     Manual     31,308 kms  Petrol
# 4             4  2017 Mahindra XUV500  Automatic     66,839 kms  Diesel
# ..          ...                   ...        ...            ...     ...
# 975         975          2017 Audi Q3  Automatic     49,980 kms  Diesel
# 976         976      2015 Maruti Ritz     Manual     28,000 kms  Petrol
# 977         977      2006 Maruti Alto     Manual     78,000 kms  Petrol
# 978         978    2017 Hyundai Verna     Manual     17,000 kms  Petrol
# 979         979       2013 Honda Brio     Manual     26,063 kms  Petrol
#
#             owner  location       Price
# 0       1st Owner  Banglore   5.39 Lakh
# ...

# %%
df3=pd.DataFrame(data3)

# %%
df3.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df3
# Out:
#               car_details    variant used_kilometer    fuel         owner  \
# 0     2019 Maruti Celerio  Automatic     37,381 kms  Petrol     1st Owner
# 1         2016 Tata Tiago     Manual     65,676 kms  Petrol     1st Owner
# 2     2017 Renault Duster  Automatic     23,322 kms  Diesel     2nd Owner
# 3    2015 Maruti Alto 800     Manual     31,308 kms  Petrol     2nd Owner
# 4    2017 Mahindra XUV500  Automatic     66,839 kms  Diesel             -
# ..                    ...        ...            ...     ...           ...
# 975          2017 Audi Q3  Automatic     49,980 kms  Diesel   First Owner
# 976      2015 Maruti Ritz     Manual     28,000 kms  Petrol  Second Owner
# 977      2006 Maruti Alto     Manual     78,000 kms  Petrol  Second Owner
# 978    2017 Hyundai Verna     Manual     17,000 kms  Petrol   First Owner
# 979       2013 Honda Brio     Manual     26,063 kms  Petrol  Second Owner
#
#      location       Price
# 0    Banglore   5.39 Lakh
# ...

# %%
data4=pd.read_csv('cars3details.csv')

# %%
data4
# Out:
#      Unnamed: 0                      car_details variant used_kilometer  \
# 0             0             2016 Maruti Alto K10  Manual     59,204 kms
# 1             1              2019 Hyundai Santro  Manual     14,162 kms
# 2             2          2018 Maruti Swift Dzire  Manual     42,048 kms
# 3             3          2012 Maruti Swift Dzire  Manual     67,616 kms
# 4             4          2017 Maruti Swift Dzire  Manual     59,190 kms
# ..          ...                              ...     ...            ...
# 641         641  2018 Mahindra Bolero Power Plus  Manual     80,000 kms
# 642         642               2007 Hyundai Verna  Manual   1,10,000 kms
# 643         643          2016 Maruti Swift Dzire  Manual   1,45,000 kms
# 644         644                 2015 Maruti Omni  Manual     50,000 kms
# 645         645          2009 Maruti Swift Dzire  Manual   1,82,602 kms
#
#        fuel         owner location      Price
# 0    Petrol     1st Owner   Jaipur  3.25 Lakh
# ...

# %%
df4=pd.DataFrame(data4)

# %%
df4.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df4
# Out:
#                          car_details variant used_kilometer    fuel  \
# 0               2016 Maruti Alto K10  Manual     59,204 kms  Petrol
# 1                2019 Hyundai Santro  Manual     14,162 kms  Petrol
# 2            2018 Maruti Swift Dzire  Manual     42,048 kms  Diesel
# 3            2012 Maruti Swift Dzire  Manual     67,616 kms  Diesel
# 4            2017 Maruti Swift Dzire  Manual     59,190 kms  Diesel
# ..                               ...     ...            ...     ...
# 641  2018 Mahindra Bolero Power Plus  Manual     80,000 kms  Diesel
# 642               2007 Hyundai Verna  Manual   1,10,000 kms  Diesel
# 643          2016 Maruti Swift Dzire  Manual   1,45,000 kms  Diesel
# 644                 2015 Maruti Omni  Manual     50,000 kms  Petrol
# 645          2009 Maruti Swift Dzire  Manual   1,82,602 kms  Diesel
#
#             owner location      Price
# 0       1st Owner   Jaipur  3.25 Lakh
# 1       1st Owner   Jaipur  4.59 Lakh
# ...

# %%
data5=pd.read_csv('cars4details.csv')

# %%
data5
# Out:
#      Unnamed: 0                car_details    variant used_kilometer    fuel  \
# 0             0       2018 Maruti Alto 800     Manual     20,132 kms  Petrol
# 1             1        2016 Maruti Wagon R     Manual     23,918 kms  Petrol
# 2             2        2016 Maruti Wagon R  Automatic     18,363 kms  Petrol
# 3             3        2018 Maruti Celerio  Automatic     21,855 kms  Petrol
# 4             4        2017 Maruti Wagon R  Automatic     23,604 kms  Petrol
# ..          ...                        ...        ...            ...     ...
# 431         431               2013 Audi A6  Automatic     67,500 kms  Diesel
# 432         432         2020 Maruti Baleno     Manual     12,000 kms  Petrol
# 433         433        2020 Hyundai Tucson  Automatic     18,000 kms  Petrol
# 434         434            2019 Kia Seltos     Manual     15,000 kms  Petrol
# 435         435  2017 Maruti Vitara Brezza     Manual   5,10,000 kms  Diesel
#
#            owner location       Price
# ...

# %%
df5=pd.DataFrame(data5)

# %%
df5.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df5
# Out:
#                    car_details    variant used_kilometer    fuel        owner  \
# 0         2018 Maruti Alto 800     Manual     20,132 kms  Petrol    1st Owner
# 1          2016 Maruti Wagon R     Manual     23,918 kms  Petrol    1st Owner
# 2          2016 Maruti Wagon R  Automatic     18,363 kms  Petrol    1st Owner
# 3          2018 Maruti Celerio  Automatic     21,855 kms  Petrol    1st Owner
# 4          2017 Maruti Wagon R  Automatic     23,604 kms  Petrol    1st Owner
# ..                         ...        ...            ...     ...          ...
# 431               2013 Audi A6  Automatic     67,500 kms  Diesel  First Owner
# 432         2020 Maruti Baleno     Manual     12,000 kms  Petrol  First Owner
# 433        2020 Hyundai Tucson  Automatic     18,000 kms  Petrol  First Owner
# 434            2019 Kia Seltos     Manual     15,000 kms  Petrol  First Owner
# 435  2017 Maruti Vitara Brezza     Manual   5,10,000 kms  Diesel  First Owner
#
#     location       Price
# ...

# %%
data6=pd.read_csv('cars5details.csv')

# %%
data6
# Out:
#      Unnamed: 0                      car_details    variant used_kilometer  \
# 0             0                   2020 MG Hector     Manual     31,000 kms
# 1             1               2016 Maruti Ertiga     Manual     53,000 kms
# 2             2               2019 Mahindra Thar     Manual     25,679 kms
# 3             3             2016 Mahindra XUV500     Manual     61,000 kms
# 4             4             2015 Volkswagen Polo     Manual     50,578 kms
# ..          ...                              ...        ...            ...
# 330         330                 2005 Maruti Alto     Manual   1,10,000 kms
# 331         331      2019 Hyundai Grand i10 Nios  Automatic     25,000 kms
# 332         332                 2017 Tata Indigo     Manual     90,000 kms
# 333         333  2019 Mahindra Bolero Power Plus     Manual     75,000 kms
# 334         334              2020 Maruti Wagon R     Manual     25,000 kms
#
#        fuel         owner location       Price
# ...

# %%
df6=pd.DataFrame(data6)

# %%
df6.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df6
# Out:
#                          car_details    variant used_kilometer    fuel  \
# 0                     2020 MG Hector     Manual     31,000 kms  Petrol
# 1                 2016 Maruti Ertiga     Manual     53,000 kms  Diesel
# 2                 2019 Mahindra Thar     Manual     25,679 kms  Diesel
# 3               2016 Mahindra XUV500     Manual     61,000 kms  Diesel
# 4               2015 Volkswagen Polo     Manual     50,578 kms  Diesel
# ..                               ...        ...            ...     ...
# 330                 2005 Maruti Alto     Manual   1,10,000 kms  Petrol
# 331      2019 Hyundai Grand i10 Nios  Automatic     25,000 kms  Petrol
# 332                 2017 Tata Indigo     Manual     90,000 kms  Diesel
# 333  2019 Mahindra Bolero Power Plus     Manual     75,000 kms  Diesel
# 334              2020 Maruti Wagon R     Manual     25,000 kms  Petrol
#
#             owner location       Price
# 0     First Owner   Indore   17.5 Lakh
# ...

# %%
data7=pd.read_csv('cars6details.csv')

# %%
data7
# Out:
#      Unnamed: 0              car_details    variant used_kilometer    fuel  \
# 0             0        2018 Maruti Swift     Manual     60,000 kms  Diesel
# 1             1           2018 Tata Hexa     Manual     15,000 kms  Diesel
# 2             2       2018 Ford Ecosport     Manual     45,000 kms  Diesel
# 3             3       2017 Ford Ecosport     Manual     40,000 kms  Diesel
# 4             4    2012 Mahindra Scorpio     Manual     58,042 kms  Diesel
# ..          ...                      ...        ...            ...     ...
# 288         288       2020 Maruti Baleno  Automatic      4,000 kms  Petrol
# 289         289      2015 Chevrolet Beat     Manual     15,000 kms  Petrol
# 290         290  2014 Tata Safari Storme     Manual     65,000 kms  Diesel
# 291         291     2008 Chevrolet Spark     Manual     20,000 kms  Petrol
# 292         292          2020 Honda City     Manual      5,000 kms  Petrol
#
#                     owner location      Price
# ...

# %%
df7=pd.DataFrame(data7)

# %%
df7.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df7
# Out:
#                  car_details    variant used_kilometer    fuel  \
# 0          2018 Maruti Swift     Manual     60,000 kms  Diesel
# 1             2018 Tata Hexa     Manual     15,000 kms  Diesel
# 2         2018 Ford Ecosport     Manual     45,000 kms  Diesel
# 3         2017 Ford Ecosport     Manual     40,000 kms  Diesel
# 4      2012 Mahindra Scorpio     Manual     58,042 kms  Diesel
# ..                       ...        ...            ...     ...
# 288       2020 Maruti Baleno  Automatic      4,000 kms  Petrol
# 289      2015 Chevrolet Beat     Manual     15,000 kms  Petrol
# 290  2014 Tata Safari Storme     Manual     65,000 kms  Diesel
# 291     2008 Chevrolet Spark     Manual     20,000 kms  Petrol
# 292          2020 Honda City     Manual      5,000 kms  Petrol
#
#                     owner location      Price
# 0             First Owner    Patna   6.4 Lakh
# 1             First Owner    Patna  12.5 Lakh
# 2    Fourth & Above Owner    Patna     8 Lakh
# ...

# %%
data8=pd.read_csv('cars7details.csv')

# %%
data8
# Out:
#      Unnamed: 0                car_details variant used_kilometer    fuel  \
# 0             0         2006 Skoda Octavia  Manual   1,10,000 kms  Diesel
# 1             1      2013 Mahindra Scorpio  Manual   1,00,000 kms  Diesel
# 2             2     2007 Maruti Zen Estilo  Manual     50,000 kms  Petrol
# 3             3        2006 Maruti Wagon R  Manual   1,20,000 kms  Petrol
# 4             4    2017 Maruti Swift Dzire  Manual   1,10,000 kms  Diesel
# ..          ...                        ...     ...            ...     ...
# 409         409       2012 Mahindra XUV500  Manual   1,15,000 kms  Diesel
# 410         410         2016 Maruti Ertiga  Manual     80,000 kms  Diesel
# 411         411  2021 Toyota Innova Crysta  Manual      5,000 kms  Petrol
# 412         412  2021 Toyota Innova Crysta  Manual      5,000 kms  Petrol
# 413         413       2016 Maruti Alto 800  Manual     65,000 kms  Petrol
#
#                     owner location       Price
# ...

# %%
df8=pd.DataFrame(data8)

# %%
df8.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df8
# Out:
#                    car_details variant used_kilometer    fuel  \
# 0           2006 Skoda Octavia  Manual   1,10,000 kms  Diesel
# 1        2013 Mahindra Scorpio  Manual   1,00,000 kms  Diesel
# 2       2007 Maruti Zen Estilo  Manual     50,000 kms  Petrol
# 3          2006 Maruti Wagon R  Manual   1,20,000 kms  Petrol
# 4      2017 Maruti Swift Dzire  Manual   1,10,000 kms  Diesel
# ..                         ...     ...            ...     ...
# 409       2012 Mahindra XUV500  Manual   1,15,000 kms  Diesel
# 410         2016 Maruti Ertiga  Manual     80,000 kms  Diesel
# 411  2021 Toyota Innova Crysta  Manual      5,000 kms  Petrol
# 412  2021 Toyota Innova Crysta  Manual      5,000 kms  Petrol
# 413       2016 Maruti Alto 800  Manual     65,000 kms  Petrol
#
#                     owner location       Price
# 0            Second Owner   Nagpur    1.5 Lakh
# 1             Third Owner   Nagpur    6.5 Lakh
# 2    Fourth & Above Owner   Nagpur    1.2 Lakh
# ...

# %%
data9=pd.read_csv('cars8details.csv')

# %%
data9
# Out:
#      Unnamed: 0           car_details    variant used_kilometer    fuel  \
# 0             0  2019 Maruti S-Presso     Manual     12,133 kms  Petrol
# 1             1     2019 Renault KWID     Manual     14,185 kms  Petrol
# 2             2     2017 Renault KWID     Manual     28,073 kms  Petrol
# 3             3      2018 Maruti Ciaz     Manual     64,789 kms  Petrol
# 4             4       2019 Honda WR-V     Manual      8,577 kms  Petrol
# ..          ...                   ...        ...            ...     ...
# 117         117      2008 Hyundai i10     Manual     70,000 kms  Petrol
# 118         118     2018 Toyota Etios     Manual     50,000 kms  Diesel
# 119         119       2010 Honda CR-V  Automatic   1,00,000 kms  Petrol
# 120         120       2019 Tata Nexon     Manual     30,000 kms  Diesel
# 121         121    2012 Mahindra Thar     Manual     96,000 kms  Diesel
#
#             owner    location      Price
# 0       1st Owner  Chandigarh   4.2 Lakh
# ...

# %%
df9=pd.DataFrame(data9)

# %%
df9.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df9
# Out:
#               car_details    variant used_kilometer    fuel         owner  \
# 0    2019 Maruti S-Presso     Manual     12,133 kms  Petrol     1st Owner
# 1       2019 Renault KWID     Manual     14,185 kms  Petrol     1st Owner
# 2       2017 Renault KWID     Manual     28,073 kms  Petrol     1st Owner
# 3        2018 Maruti Ciaz     Manual     64,789 kms  Petrol     1st Owner
# 4         2019 Honda WR-V     Manual      8,577 kms  Petrol     1st Owner
# ..                    ...        ...            ...     ...           ...
# 117      2008 Hyundai i10     Manual     70,000 kms  Petrol  Second Owner
# 118     2018 Toyota Etios     Manual     50,000 kms  Diesel   First Owner
# 119       2010 Honda CR-V  Automatic   1,00,000 kms  Petrol  Second Owner
# 120       2019 Tata Nexon     Manual     30,000 kms  Diesel   First Owner
# 121    2012 Mahindra Thar     Manual     96,000 kms  Diesel   Third Owner
#
#        location      Price
# 0    Chandigarh   4.2 Lakh
# ...

# %%
data10=pd.read_csv('cars9details.csv')

# %%
data10
# Out:
#      Unnamed: 0              car_details    variant used_kilometer    fuel  \
# 0             0   2017 Hyundai Grand i10     Manual     49,819 kms  Petrol
# 1             1        2016 Renault KWID     Manual     28,437 kms  Petrol
# 2             2        2019 Tata Harrier     Manual     93,703 kms  Diesel
# 3             3     2020 Maruti Alto 800     Manual     11,628 kms  Petrol
# 4             4       2015 Ford Ecosport     Manual     64,524 kms  Diesel
# ..          ...                      ...        ...            ...     ...
# 204         204      2017 Maruti Wagon R  Automatic     27,347 kms  Petrol
# 205         205     2013 Volkswagen Polo     Manual     77,045 kms  Diesel
# 206         206        2012 Toyota Etios     Manual   1,02,243 kms  Diesel
# 207         207  2013 Maruti Swift Dzire     Manual   1,20,000 kms  Petrol
# 208         208  2015 Maruti Swift Dzire     Manual     50,000 kms  Petrol
#
#            owner location       Price
# ...

# %%
df10=pd.DataFrame(data10)

# %%
df10.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df10
# Out:
#                  car_details    variant used_kilometer    fuel        owner  \
# 0     2017 Hyundai Grand i10     Manual     49,819 kms  Petrol    1st Owner
# 1          2016 Renault KWID     Manual     28,437 kms  Petrol            -
# 2          2019 Tata Harrier     Manual     93,703 kms  Diesel    1st Owner
# 3       2020 Maruti Alto 800     Manual     11,628 kms  Petrol    1st Owner
# 4         2015 Ford Ecosport     Manual     64,524 kms  Diesel    1st Owner
# ..                       ...        ...            ...     ...          ...
# 204      2017 Maruti Wagon R  Automatic     27,347 kms  Petrol  First Owner
# 205     2013 Volkswagen Polo     Manual     77,045 kms  Diesel  First Owner
# 206        2012 Toyota Etios     Manual   1,02,243 kms  Diesel  First Owner
# 207  2013 Maruti Swift Dzire     Manual   1,20,000 kms  Petrol  First Owner
# 208  2015 Maruti Swift Dzire     Manual     50,000 kms  Petrol  First Owner
#
#     location       Price
# 0    Udaipur   4.83 Lakh
# ...

# %%
data11=pd.read_csv('cars10details.csv')

# %%
data11
# Out:
#      Unnamed: 0              car_details    variant used_kilometer    fuel  \
# 0             0      2019 Mahindra Supro     Manual     20,000 kms  Diesel
# 1             1         2006 Honda Civic  Automatic     70,040 kms  Petrol
# 2             2          2010 Honda City  Automatic     60,540 kms  Petrol
# 3             3       2019 Ford Ecosport     Manual     20,000 kms  Diesel
# 4             4         2005 Maruti Alto     Manual   1,10,000 kms  Petrol
# ..          ...                      ...        ...            ...     ...
# 105         105      2016 Maruti Wagon R     Manual     45,000 kms  Petrol
# 106         106  2017 Maruti Swift Dzire     Manual     40,000 kms  Petrol
# 107         107     2015 Maruti Alto 800     Manual     40,000 kms  Petrol
# 108         108     2014 Maruti Alto K10     Manual     35,000 kms  Petrol
# 109         109         2015 Maruti Ciaz     Manual   1,20,000 kms  Diesel
#
#             owner location      Price
# ...

# %%
df11=pd.DataFrame(data11)

# %%
df11.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df11
# Out:
#                  car_details    variant used_kilometer    fuel         owner  \
# 0        2019 Mahindra Supro     Manual     20,000 kms  Diesel   First Owner
# 1           2006 Honda Civic  Automatic     70,040 kms  Petrol  Second Owner
# 2            2010 Honda City  Automatic     60,540 kms  Petrol   First Owner
# 3         2019 Ford Ecosport     Manual     20,000 kms  Diesel   First Owner
# 4           2005 Maruti Alto     Manual   1,10,000 kms  Petrol  Second Owner
# ..                       ...        ...            ...     ...           ...
# 105      2016 Maruti Wagon R     Manual     45,000 kms  Petrol  Second Owner
# 106  2017 Maruti Swift Dzire     Manual     40,000 kms  Petrol   First Owner
# 107     2015 Maruti Alto 800     Manual     40,000 kms  Petrol   First Owner
# 108     2014 Maruti Alto K10     Manual     35,000 kms  Petrol   First Owner
# 109         2015 Maruti Ciaz     Manual   1,20,000 kms  Diesel   First Owner
#
#     location      Price
# ...

# %%
data12=pd.read_csv('cars11details.csv')

# %%
data12
# Out:
#      Unnamed: 0              car_details variant used_kilometer    fuel  \
# 0             0        2016 Renault KWID  Manual     28,437 kms  Petrol
# 1             1   2017 Hyundai Grand i10  Manual     49,819 kms  Petrol
# 2             2        2019 Tata Harrier  Manual     93,703 kms  Diesel
# 3             3     2020 Maruti Alto 800  Manual     11,628 kms  Petrol
# 4             4       2015 Ford Ecosport  Manual     64,524 kms  Diesel
# ..          ...                      ...     ...            ...     ...
# 217         217  2012 Tata Safari Storme  Manual   1,24,009 kms  Diesel
# 218         218       2017 Maruti Baleno  Manual      5,000 kms  Petrol
# 219         219          2020 Tata Tiago  Manual     55,000 kms  Petrol
# 220         220       2013 Toyota Innova  Manual     80,000 kms  Diesel
# 221         221        2017 Jeep Compass  Manual     59,000 kms  Diesel
#
#             owner location       Price
# 0       1st Owner     Kota   3.02 Lakh
# ...

# %%
df12=pd.DataFrame(data12)

# %%
df12.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df12
# Out:
#                  car_details variant used_kilometer    fuel         owner  \
# 0          2016 Renault KWID  Manual     28,437 kms  Petrol     1st Owner
# 1     2017 Hyundai Grand i10  Manual     49,819 kms  Petrol     1st Owner
# 2          2019 Tata Harrier  Manual     93,703 kms  Diesel     1st Owner
# 3       2020 Maruti Alto 800  Manual     11,628 kms  Petrol     1st Owner
# 4         2015 Ford Ecosport  Manual     64,524 kms  Diesel     1st Owner
# ..                       ...     ...            ...     ...           ...
# 217  2012 Tata Safari Storme  Manual   1,24,009 kms  Diesel   First Owner
# 218       2017 Maruti Baleno  Manual      5,000 kms  Petrol   First Owner
# 219          2020 Tata Tiago  Manual     55,000 kms  Petrol  Second Owner
# 220       2013 Toyota Innova  Manual     80,000 kms  Diesel   First Owner
# 221        2017 Jeep Compass  Manual     59,000 kms  Diesel  Second Owner
#
#     location       Price
# 0       Kota   3.02 Lakh
# 1       Kota   4.83 Lakh
# ...

# %%
df13=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12],axis=0)

# %%
df13
# Out:
#                  car_details variant used_kilometer    fuel         owner  \
# 0          2008 Maruti Swift  Manual     73,000 kms  Petrol  Second Owner
# 1           2011 Hyundai i20  Manual     70,000 kms  Petrol   First Owner
# 2      2015 Mahindra TUV 300  Manual     67,000 kms  Diesel   First Owner
# 3       2014 Mahindra XUV500  Manual     90,000 kms  Diesel   First Owner
# 4           2013 Skoda Rapid  Manual     63,000 kms  Diesel  Second Owner
# ..                       ...     ...            ...     ...           ...
# 217  2012 Tata Safari Storme  Manual   1,24,009 kms  Diesel   First Owner
# 218       2017 Maruti Baleno  Manual      5,000 kms  Petrol   First Owner
# 219          2020 Tata Tiago  Manual     55,000 kms  Petrol  Second Owner
# 220       2013 Toyota Innova  Manual     80,000 kms  Diesel   First Owner
# 221        2017 Jeep Compass  Manual     59,000 kms  Diesel  Second Owner
#
#     location      Price
# 0     Mumbai  2.15 Lakh
# 1     Mumbai  3.15 Lakh
# ...

# %%
df13.to_csv('Finalcardetails1.csv')

# %%
df13
# Out:
#                  car_details variant used_kilometer    fuel         owner  \
# 0          2008 Maruti Swift  Manual     73,000 kms  Petrol  Second Owner
# 1           2011 Hyundai i20  Manual     70,000 kms  Petrol   First Owner
# 2      2015 Mahindra TUV 300  Manual     67,000 kms  Diesel   First Owner
# 3       2014 Mahindra XUV500  Manual     90,000 kms  Diesel   First Owner
# 4           2013 Skoda Rapid  Manual     63,000 kms  Diesel  Second Owner
# ..                       ...     ...            ...     ...           ...
# 217  2012 Tata Safari Storme  Manual   1,24,009 kms  Diesel   First Owner
# 218       2017 Maruti Baleno  Manual      5,000 kms  Petrol   First Owner
# 219          2020 Tata Tiago  Manual     55,000 kms  Petrol  Second Owner
# 220       2013 Toyota Innova  Manual     80,000 kms  Diesel   First Owner
# 221        2017 Jeep Compass  Manual     59,000 kms  Diesel  Second Owner
#
#     location      Price
# 0     Mumbai  2.15 Lakh
# 1     Mumbai  3.15 Lakh
# ...
